# %% [markdown]
# <a href="https://colab.research.google.com/github/Qbaxxx/MAD_SWPS_Jakub_Babinski_Grupa_3/blob/main/MAD_Kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
car: pd.DataFrame = pd.read_csv('/content/drive/MyDrive/MAD/bmw.csv')

# %%
car
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1       6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2       5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3       1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4       7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 10776         X3  2016  19000    Automatic    40818   Diesel  150  54.3
# 10777   5 Series  2016  14600    Automatic    42947   Diesel  125  60.1
# 10778   3 Series  2017  13100       Manual    25468   Petrol  200  42.8
# 10779   1 Series  2014   9930    Automatic    45000   Diesel   30  64.2
# 10780         X1  2017  15981    Automatic    59432   Diesel  125  57.6
#
#        engineSize
# 0             2.0
# 1             2.0
# 2             3.0
# 3             1.5
# ...

# %%
car.head(n=10)
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
# 5   5 Series  2016  14900    Automatic    35309   Diesel  125  60.1
# 6   5 Series  2017  16000    Automatic    38538   Diesel  125  60.1
# 7   2 Series  2018  16250       Manual    10401   Petrol  145  52.3
# 8   4 Series  2017  14250       Manual    42668   Diesel   30  62.8
# 9   5 Series  2016  14250    Automatic    36099   Diesel   20  68.9
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0
# 5         2.0
# 6         2.0
# 7         1.5
# 8         2.0
# 9         2.0

# %%
car.tail(n=4)
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 10777   5 Series  2016  14600    Automatic    42947   Diesel  125  60.1
# 10778   3 Series  2017  13100       Manual    25468   Petrol  200  42.8
# 10779   1 Series  2014   9930    Automatic    45000   Diesel   30  64.2
# 10780         X1  2017  15981    Automatic    59432   Diesel  125  57.6
#
#        engineSize
# 10777         2.0
# 10778         2.0
# 10779         2.0
# 10780         2.0

# %%
car.columns
# Out:
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize'],
#       dtype='object')

# %%
car.index
# Out:
# RangeIndex(start=0, stop=10781, step=1)

# %%
car.dtypes
# Out:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
car.dtypes.value_counts()
# Out:
# int64      4
# object     3
# float64    2
# Name: count, dtype: int64

# %%
car.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  10781.000000   10781.000000   10781.000000  10781.000000  10781.000000
# mean    2017.078935   22733.408867   25496.986550    131.702068     56.399035
# std        2.349038   11415.528189   25143.192559     61.510755     31.336958
# min     1996.000000    1200.000000       1.000000      0.000000      5.500000
# 25%     2016.000000   14950.000000    5529.000000    135.000000     45.600000
# 50%     2017.000000   20462.000000   18347.000000    145.000000     53.300000
# 75%     2019.000000   27940.000000   38206.000000    145.000000     62.800000
# max     2020.000000  123456.000000  214000.000000    580.000000    470.800000
#
#          engineSize
# count  10781.000000
# mean       2.167767
# std        0.552054
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        6.600000

# %%
col: pd.Series = car['model']
col
# Out:
# 0         5 Series
# 1         6 Series
# 2         5 Series
# 3         1 Series
# 4         7 Series
#            ...
# 10776           X3
# 10777     5 Series
# 10778     3 Series
# 10779     1 Series
# 10780           X1
# Name: model, Length: 10781, dtype: object

# %%
car.model
# Out:
# 0         5 Series
# 1         6 Series
# 2         5 Series
# 3         1 Series
# 4         7 Series
#            ...
# 10776           X3
# 10777     5 Series
# 10778     3 Series
# 10779     1 Series
# 10780           X1
# Name: model, Length: 10781, dtype: object

# %%
car[['model', 'year', 'price']].head()
# Out:
#        model  year  price
# 0   5 Series  2014  11200
# 1   6 Series  2018  27000
# 2   5 Series  2016  16000
# 3   1 Series  2017  12750
# 4   7 Series  2014  14500

# %%
car.select_dtypes(include='object').head()
# Out:
#        model transmission fuelType
# 0   5 Series    Automatic   Diesel
# 1   6 Series    Automatic   Petrol
# 2   5 Series    Automatic   Diesel
# 3   1 Series    Automatic   Diesel
# 4   7 Series    Automatic   Diesel

# %%
car.filter(like='fu').head(n=10)
# Out:
#   fuelType
# 0   Diesel
# 1   Petrol
# 2   Diesel
# 3   Diesel
# 4   Diesel
# 5   Diesel
# 6   Diesel
# 7   Petrol
# 8   Diesel
# 9   Diesel
